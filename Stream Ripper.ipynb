# %% [markdown]
# #`mountUmount(`<font size="3px" color="#01c968">`Gdrive`</font>`)`

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount Gdrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive! 
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")

# %% [markdown]
# #<font size="5">← ឵឵<i>Install Tools </font>

# %%
from IPython.display import clear_output
import os, urllib.request
from os import chdir
HOME = os.path.expanduser("~")
pathDoneCMD = f'{HOME}/doneCMD.sh'
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/yunooooo/gcct/master/res/ttmg.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")

from ttmg import (
    loadingAn,
    textAn,
)

loadingAn(name="lds")
textAn("Installing Dependencies...", ty='twg')
#os.system('pip install git+git://github.com/AWConant/jikanpy.git')
os.system('add-apt-repository -y ppa:jonathonf/ffmpeg-4')
os.system('apt-get update')
#os.system('apt install mediainfo')
os.system('apt-get install ffmpeg')
os.system('python3 -m pip install -U yt-dlp')
os.system('apt-get install aria2')
os.system('apt-get install mkvtoolnix')
# !sudo mkdir "/tmp"
chdir("/tmp")
# !sudo apt install git
# !git clone https://github.com/axiomatic-systems/Bento4.git
chdir("/tmp/Bento4")
# !sudo mkdir "/tmp/Bento4/cmakebuild"
chdir("/tmp/Bento4/cmakebuild")
# !cmake -DCMAKE_BUILD_TYPE=Release ..
# !make
# !sudo make install
chdir("/content")
# !wget -q "http://archive.ubuntu.com/ubuntu/pool/universe/libm/libmms/libmms0_0.6.4-2_amd64.deb" "https://mediaarea.net/download/binary/libzen0/0.4.39/libzen0v5_0.4.39-1_amd64.xUbuntu_18.04.deb" "https://mediaarea.net/download/binary/mediainfo/21.03/mediainfo_21.03-1_amd64.xUbuntu_18.04.deb" "https://mediaarea.net/download/binary/libmediainfo0/21.03/libmediainfo0v5_21.03-1_amd64.xUbuntu_18.04.deb"
# !sudo dpkg -i /content/*.deb
# !rm -rf /content/*.deb
# !mediainfo --Version
clear_output()
print('Installation finished.')
#@markdown <h3>⬅️ Run This Cell to Install Tools</h3>
from IPython.display import HTML, clear_output
from google.colab import drive
import json
import ipywidgets as widgets
get_ipython().system_raw('pip3 install opencv-python')
from IPython.display import HTML, clear_output
import ipywidgets as widgets
import base64
import json
import requests
import numpy as np
import os
from base64 import b64encode
def MakeLabel(description, button_style):
  return widgets.Button(description=description, disabled=True, button_style=button_style)
clear_output()
display(MakeLabel("✔ Successfull", "success"))
client_id = 'c0d03bba24c7c0e'
headers={"Authorization":"Client-ID "+client_id}
np.save('imgur_u3eight.npy', headers) 
url = "https://api.imgur.com/3/upload.json"

! mkdir -p /root/.uaudith
! mv imgur_u3eight.npy /root/.uaudith/

def upload(filename):
  j1 = requests.post(
      url,
      headers = np.load('/root/.uaudith/imgur_u3eight.npy',allow_pickle=True).item(),
      data = {
          
          'image': b64encode(open(filename, 'rb').read()),
          'type': 'base64',
          'name': str(filename),
          'title': filename+' by u38'
      }
  )
  data = json.loads(j1.text)['data']
  print (data['link'], data['id'], data['deletehash'],str(filename))
  return data['link']
def MakeLabel(description, button_style):
  return widgets.Button(description=description, disabled=True, button_style=button_style)

# %% [markdown]
# #<font size="5">឵឵឵឵<i>Video Tools</font>

# %%
import os, sys
from os import chdir
from IPython.display import clear_output
Path = "/content/drive/Shareddrives/Uploads/RIPS"
Name = "" #@param {type:"string"}
MPD = "" #@param {type:"string"}
Key = "" #@param {type:"string"}
Res = "1080" #@param ["1080", "720","540","480","360"]
Subtitles = ""  #@param {type:"string"}
Service = "CRIT" #@param ["KNPY","MUBI", "FNDR","CRIT","TENK","MDCI","OVID"]
if Service == 'OVID':
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  MPD = MPD.replace("json","m3u8")
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  Path+='/'
  # !yt-dlp --external-downloader aria2c -f "bv+audio-high-audio" "$MPD" -o "$Path"video.ts
  if (Subtitles == ""):
    # !mkvmerge -o "$Path""$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv --title "$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts.mp4
  else:
    # !wget -O "$Path"/subs.vtt "$Subtitles"
    # !ffmpeg -i "$Path"subs.vtt "$Path"subs.srt
    # !mkvmerge -o "$Path""$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts.mp4 --language 0:eng "$Path"subs.srt
  vidfilepath=Path+"/video.ts.mp4"
  os.remove(vidfilepath)
  clear_output()
elif Service == 'MDCI':
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  Path+='/'
  # !yt-dlp --external-downloader aria2c -f "best[height<=$Res]" "$MPD" -o "$Path"video.ts
  if (Subtitles == ""):
    # !mkvmerge -o "$Path""$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv --title "$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts
  else:
    # !yt-dlp --external-downloader aria2c "$Subtitles" -o "$Path"subs.vtt
    # !ffmpeg -i "$Path"subs.vtt "$Path"subs.srt
    # !mkvmerge -o "$Path""$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv --title "$Name".'$Res'p.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts --language 0:eng "$Path"subs.srt
    subfilepath=Path+"/subs.srt"
    os.remove(subfilepath)
  vidfilepath=Path+"/video.ts"
  os.remove(vidfilepath)
  clear_output()
  print('Ripping finished.')
elif Service == 'TENK':
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  Path+='/'
  list = MPD.split(",")
  if (len(list) == 1):
    # !yt-dlp --external-downloader aria2c -f "bv+ba" "$MPD" -o "$Path"video.ts
    if (Subtitles == ""):
      # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.h264-CANDY.mkv --title "$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts.mp4
    else:
      # !wget -O "$Path"/subs.srt "$Subtitles"
      # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.h264-CANDY.mkv "$Path"video.ts.mp4 --language 0:eng "$Path"subs.srt
  elif (len(list) == 2):
    mpd1 = list[0]
    mpd2 = list[1]
    # !yt-dlp --external-downloader aria2c -f "bv" "$mpd1" -o "$Path"video.ts
    # !yt-dlp --external-downloader aria2c "$mpd2" -o "$Path"audio.mp4
    if (Subtitles == ""):
      # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.h264-CANDY.mkv "$Path"video.ts.mp4 "$Path"audio.mp4
    else:
      # !wget -O "$Path"/subs.srt "$Subtitles"
      # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.h264-CANDY.mkv "$Path"video.ts.mp4 "$Path"audio.mp4 --language 0:eng "$Path"subs.srt
  vidfilepath=Path+"/video.ts.mp4"
  os.remove(vidfilepath)
  if (len(list) ==2):
    audfilepath=Path+"/audio.mp4"
    os.remove(audfilepath)
  clear_output()
  print('Ripping finished.')
elif Service == 'FNDR':
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  Path+='/'
  # !yt-dlp --external-downloader aria2c -f "bv+ba" "$MPD" -o "$Path"video.ts
  if (Subtitles == ""):
    # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.x264-CANDY.mkv --title "$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts
  else:
    # !wget -O "$Path"/subs.vtt "$Subtitles"
    # !ffmpeg -i "$Path"subs.vtt "$Path"subs.srt
    # !mkvmerge -o "$Path""$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts --language 0:eng "$Path"subs.srt
    subfilepath=Path+"/subs.srt"
    os.remove(subfilepath)
  vidfilepath=Path+"/video.ts"
  os.remove(vidfilepath)
  clear_output()
  print('Ripping finished.')
elif Service == 'KNPY' and 'm3u8' in MPD:
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  Path+='/'
  # !yt-dlp --external-downloader aria2c -f "bv+ba" "$MPD" -o "$Path"video.ts
  if (Subtitles == ""):
    # !mkvmerge -o "$Path""$Name"."$Res"p."$Service".WEB-DL.AAC.2.0.x264-CANDY.mkv --title "$Name".'$Res'p.'$Service'.WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts
  else:
    # !wget -O "$Path"/subs.vtt "$Subtitles"
    # !ffmpeg -i "$Path"subs.vtt "$Path"subs.srt
    # !mkvmerge -o "$Path""$Name"."$Res"p."$Service".WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"video.ts --language 0:eng "$Path"subs.srt
  vidfilepath=Path+"/video.ts"
  os.remove(vidfilepath)
  clear_output()
  print('Ripping finished.')
else:
  # !sudo mkdir "$Path/$Name"
  Path = Path+'/'+Name
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -F "$MPD" -v
  # !yt-dlp --external-downloader aria2c --allow-unplayable-formats -f 'bv+ba' "$MPD" -o "$Path/encrypted.(ext)s"
  if Service == 'MUBI':
    # !yt-dlp --external-downloader aria2c --skip-download --write-subs --sub-langs "en," --allow-unplayable-formats "$MPD" -o "$Path/subs.srt"
    # !mv "$Path/subs.srt.en.mp4" "$Path/subs.srt"
  import os, sys, re, pathlib
  location = Path
  if(location[-1]!="/"):
    location+="/"
  os.chdir(location)
  NewNameofFile=""
  extensions = ["mp4","mkv","m4a","ts","html","htm","m4v","ipynb","jpg","jpeg","txt","png","pdf","docx","srt"]
  name_extensions= "mp4"
  name_extensions = name_extensions.split(",")
  tuple_extensions = tuple(name_extensions)
  for root,directories,files in os.walk("."): 
      for f in files:
          extension = f.split(".")[-1]
          if extension in extensions:
              filepath=os.path.join(root,f)
              input_file= location + filepath
              delsplit = re.search("\/(?:.(?!\/))+$", input_file)
              filename = re.sub("^[\/]", "", delsplit.group(0))
              filename_raw = re.sub(".{4}$", "", filename)
              file_extension = re.search(".{3}$", filename)
              file_extension_raw = file_extension.group(0)
              os.environ['inputFile'] = input_file
              input_array = input_file.split("/")
              file_arr = input_array[-1].split(".")
              file_arr.pop()
              input_array.pop()
              NameofFile='.'.join(file_arr) 
              NWEX = NameofFile + "." + extension
              if (NWEX.endswith(tuple_extensions) == 1):
                NewNameofFile="video"+"."+"mp4"
                os.environ['fileName'] = NewNameofFile
                os.environ['outputPath'] = '/'.join(input_array) + "/"
                os.environ['fileName'] = NewNameofFile
                os.environ['outputPath'] = '/'.join(input_array) + "/"
                src=input_file
                dst='/'.join(input_array) + "/" + NewNameofFile
                os.rename(src, dst)
  if(location[-1]!="/"):
    location+="/"
  os.chdir(location)
  NewNameofFile=""
  name_extensions= "m4a"
  name_extensions = name_extensions.split(",")
  tuple_extensions = tuple(name_extensions)
  for root,directories,files in os.walk("."): 
      for f in files:
          extension = f.split(".")[-1]
          if extension in extensions:
              filepath=os.path.join(root,f)
              input_file= location + filepath
              delsplit = re.search("\/(?:.(?!\/))+$", input_file)
              filename = re.sub("^[\/]", "", delsplit.group(0))
              filename_raw = re.sub(".{4}$", "", filename)
              file_extension = re.search(".{3}$", filename)
              file_extension_raw = file_extension.group(0)
              os.environ['inputFile'] = input_file
              input_array = input_file.split("/")
              file_arr = input_array[-1].split(".")
              file_arr.pop()
              input_array.pop()
              NameofFile='.'.join(file_arr) 
              NWEX = NameofFile + "." + extension
              if (NWEX.endswith(tuple_extensions) == 1):
                NewNameofFile="audio"+"."+"m4a"
                os.environ['fileName'] = NewNameofFile
                os.environ['outputPath'] = '/'.join(input_array) + "/"
                os.environ['fileName'] = NewNameofFile
                os.environ['outputPath'] = '/'.join(input_array) + "/"
                src=input_file
                dst='/'.join(input_array) + "/" + NewNameofFile
                os.rename(src, dst)

  # !mp4decrypt --key "$Key" "$Path/audio.m4a" "$Path/audiod.m4a"
  # !mp4decrypt --key "$Key" "$Path/video.mp4" "$Path/videod.mp4"
  vidfilepath=Path+"/video.mp4"
  os.remove(vidfilepath)
  audfilepath=Path+"/audio.m4a"
  os.remove(audfilepath)
  Path+='/'
  if (Subtitles == ""):
    # !mkvmerge -o "$Path""$Name"."$Res"p."$Service".WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"videod.mp4 "$Path"audiod.m4a
  else:
    # !wget -O "$Path"/subs.vtt "$Subtitles"
    # !ffmpeg -i "$Path"subs.vtt "$Path"subs.srt
    # !mkvmerge -o "$Path""$Name"."$Res"p."$Service".WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"videod.mp4 "$Path"audiod.m4a --language 0:eng "$Path"subs.srt
  if Service == 'MUBI':
    # !mkvmerge -o "$Path""$Name"."$Res"p."$Service".WEB-DL.AAC.2.0.x264-CANDY.mkv "$Path"videod.mp4 "$Path"audiod.m4a --language 0:eng "$Path"subs.srt
    subfilepath=Path+"/subs.srt"
    os.remove(subfilepath)
  vidfilepath=Path+"/videod.mp4"
  os.remove(vidfilepath)
  audfilepath=Path+"/audiod.m4a"
  os.remove(audfilepath)
  clear_output()
  print('Ripping finished.')

# %%
import os

#@markdown <h3>⬅️ Media Info</h3>
Path = "" #@param {type:"string"}
media = !mediainfo "$Path"
get_ipython().system_raw("""mediainfo --LogFile="/root/.nfo" "$Path" """)
with open('/root/.nfo', 'r') as file:
    media = file.read()
    media = media.replace(os.path.dirname(Path)+"/", "")
print(media)

# %%
#@markdown <h3>⬅️ Screenshot Generator</h3>
#get_ipython().system_raw('python3 -m pip install -U hachoir')
get_ipython().system_raw('pip3 install opencv-python')
import random, string, urllib.request, json, getpass, os, time, IPython, uuid
import ipywidgets as widgets
from IPython.display import HTML, clear_output
import subprocess
import os
import numpy as np
video_path = "" #@param {type:"string"}
your_watermark = ""
send_to_imgur = True
save_to_drive = False

def err():
  display(HTML("<center><h2 style=\"font-family:Trebuchet MS;color:#008000;\">No api key Detected. Run Configuration !</h2><br></center>"))
import cv2
path=video_path.split('/')
filename=path[-1]
framelist=[]
path[-1]=''

#frame length
cap = cv2.VideoCapture(video_path)
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print( length )
print('The video you have selected has',length,'frames')
totscr=3
for i in range(1,totscr+1):
    framelist.append(round((i/(totscr+1))*length))
#
pathstr = '/'.join(str(part)for part in path)
# Opens the Video file
cap= cv2.VideoCapture(video_path)
i=0
# get coords based on boundary
#textX = round((frame.shape[1] - textsize[0]) / 2)
#textY = round((frame.shape[0] + textsize[1]) / 2)
clear_output()
for k in framelist:
   cap.set(1,int(k))
   ret, frame = cap.read()

   if ret == False:
        break   
   if not(your_watermark==""):
      # get boundary of this text
      height, width, channels = frame.shape
      font = cv2.FONT_HERSHEY_SIMPLEX
      textsize = cv2.getTextSize(your_watermark, font, min(width,height)/(1000), 2)[0]
      
      cv2.putText(frame,your_watermark,(round(width*1/32),round(height-3*textsize[1])), font, 1.5*min(width,height)/(1000),(255,255,255),1,cv2.LINE_AA)
   cv2.imwrite(filename+str(k)+'.png',frame)
   if send_to_imgur==True:
    if os.path.exists('/root/.uaudith/imgur_u3eight.npy'):

        upload(filename+str(k)+'.png')
    else:
        err()
   if save_to_drive == True:
      p1 = subprocess.Popen(["mv", filename+str(k)+'.png',pathstr+str('screens_by_u3eight/')], stdout=subprocess.PIPE)
    

cap.release()
cv2.destroyAllWindows()
#clear_output()
display(HTML("<center><h2 style=\"font-family:Trebuchet MS;color:#008000;\">All done</h2><br></center>"))
